# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import scipy as sp
import pandas as pd
import seaborn as sns
import os
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
#import umap
import glob
from sklearn.tree import DecisionTreeRegressor
from sklearn.feature_selection import SelectFromModel
from fcmeans import FCM
from sklearn.datasets import make_blobs
from matplotlib import pyplot as plt
from seaborn import scatterplot as scatter
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.mixture import GaussianMixture
from sklearn.preprocessing import MinMaxScaler
from scipy import signal
from PyAstronomy import pyasl
from sklearn.metrics import mean_squared_error
from scipy.signal import savgol_filter
from sklearn import preprocessing, svm
from sklearn.model_selection import cross_validate
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
cool0=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\cooling_channels0.csv', sep=',',  index_col=0)
cool1=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\cooling_channels1.csv', sep=',',  index_col=0)
cool2=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\cooling_channels2.csv', sep=',',  index_col=0)
cool3=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\cooling_channels3.csv', sep=',',  index_col=0)

core0=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\core_channels0.csv', sep=',',  index_col=0)
core1=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\core_channels1.csv', sep=',',  index_col=0)
core2=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\core_channels2.csv', sep=',',  index_col=0)
core3=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\core_channels3.csv', sep=',',  index_col=0)

ep0=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\ep_channels0.csv', sep=',',  index_col=0)
ep1=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\ep_channels1.csv', sep=',',  index_col=0)
ep2=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\ep_channels2.csv', sep=',',  index_col=0)
ep3=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\ep_channels3.csv', sep=',',  index_col=0)

inj0=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\injection_channels0.csv', sep=',',  index_col=0)
inj1=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\injection_channels1.csv', sep=',',  index_col=0)
inj2=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\injection_channels2.csv', sep=',',  index_col=0)
inj3=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\injection_channels3.csv', sep=',',  index_col=0)

lub0=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\lub_channels0.csv', sep=',',  index_col=0)
lub1=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\lub_channels1.csv', sep=',',  index_col=0)
lub2=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\lub_channels2.csv', sep=',',  index_col=0)
lub3=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\lub_channels3.csv', sep=',',  index_col=0)

num0=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\num_channels0.csv', sep=',',  index_col=0)
num1=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\num_channels1.csv', sep=',',  index_col=0)
num2=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\num_channels2.csv', sep=',',  index_col=0)
num3=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\num_channels3.csv', sep=',',  index_col=0)

tie0=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\tiebar_channels0.csv', sep=',',  index_col=0)
tie1=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\tiebar_channels1.csv', sep=',',  index_col=0)
tie2=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\tiebar_channels2.csv', sep=',',  index_col=0)
tie3=pd.read_csv(r'D:\UserData\z0041t8e\Documents\Projects\3_TICO2\Compiled_Data\tiebar_channels3.csv', sep=',',  index_col=0)

# %%
files_clusters = pd.read_csv(r'files_clusters_map.csv', sep=',',  index_col=0)

# %%
#cluster_ftrs = [[]] * 8
cluster_ftrs[0] = np.asarray(pd.read_csv('ftrs_0.csv', header=None).values.T).ravel()
cluster_ftrs[1] = np.asarray(pd.read_csv('ftrs_1.csv', header=None).values.T).ravel()
cluster_ftrs[2] = np.asarray(pd.read_csv('ftrs_2.csv', header=None).values.T).ravel()
cluster_ftrs[3] = np.asarray(pd.read_csv('ftrs_3.csv', header=None).values.T).ravel()
cluster_ftrs[4] = np.asarray(pd.read_csv('ftrs_4.csv', header=None).values.T).ravel()
cluster_ftrs[5] = np.asarray(pd.read_csv('ftrs_5.csv', header=None).values.T).ravel()
cluster_ftrs[6] = np.asarray(pd.read_csv('ftrs_6.csv', header=None).values.T).ravel()
cluster_ftrs[7] = np.asarray(pd.read_csv('ftrs_7.csv', header=None).values.T).ravel()

# %%
cluster_ftrs
# Out:
# [array(['fDie1wflow_en3', 'fDie1wflow_mse', 'fDie2wflow_en1',
#         'fDie2wflow_mse', 'fDie2wflow_mae', 'mDie1wflow_mse',
#         'mDie1wflow_mae', 'mDie2wflow_en0', 'mDie2wflow_en3',
#         'mDie2wflow_mse', 'mDie3wflow_en1', 'mDie3wflow_mse',
#         'mDie3wflow_mae', 'sleevewflow_mse', 'tipwflow_en3', 'core3_mse',
#         'core4_mse', 'core5_mse', 'core6_mse', 'core6_mae', 'ep_en17',
#         'ep_mse', 'injection_en0', 'injection_en27', 'injection_en29',
#         'shot_Vel1', 'shot_Vel2', 'tiebar_en3', 'tiebar_mse'], dtype=object),
#  array(['fDie1wflow_en0', 'fDie1wflow_en1', 'fDie1wflow_en2',
#         'fDie1wflow_en3', 'fDie1wflow_en4', 'fDie1wflow_mse',
#         'fDie1wflow_mae', 'fDie2wflow_en2', 'fDie2wflow_en3',
#         'fDie2wflow_en4', 'fDie2wflow_mse', 'fDie2wflow_mae',
#         'mDie1wflow_en1', 'mDie1wflow_en2', 'mDie1wflow_en3',
#         'mDie1wflow_en4', 'mDie1wflow_mae', 'mDie2wflow_en2',
# ...

# %%
print(cool0.shape)
print(cool1.shape)
print(cool2.shape)
print(cool3.shape)
# Out:
# (23041, 841)
# (32054, 841)
# (37049, 841)
# (18846, 841)

# %%
print(cool1.shape)
print(core1.shape)
print(ep1.shape)
print(inj1.shape)
print(lub1.shape)
print(num1.shape)
print(tie1.shape)
# Out:
# (32054, 841)
# (32054, 18001)
# (32054, 601)
# (32054, 9001)
# (32054, 301)
# (32054, 13)
# (32054, 4001)

# %%
cool0.columns.values #7 feeture with 2 time series for each fearture (14 time sieries) T = 1sec, duration =60sec
# Out:
# array(['File_No', 'fDie1wflow_volume_0.000sec',
#        'fDie1wflow_volume_1.000sec', 'fDie1wflow_volume_2.000sec',
#        'fDie1wflow_volume_3.000sec', 'fDie1wflow_volume_4.000sec',
#        'fDie1wflow_volume_5.000sec', 'fDie1wflow_volume_6.000sec',
#        'fDie1wflow_volume_7.000sec', 'fDie1wflow_volume_8.000sec',
#        'fDie1wflow_volume_9.000sec', 'fDie1wflow_volume_10.000sec',
#        'fDie1wflow_volume_11.000sec', 'fDie1wflow_volume_12.000sec',
#        'fDie1wflow_volume_13.000sec', 'fDie1wflow_volume_14.000sec',
#        'fDie1wflow_volume_15.000sec', 'fDie1wflow_volume_16.000sec',
#        'fDie1wflow_volume_17.000sec', 'fDie1wflow_volume_18.000sec',
#        'fDie1wflow_volume_19.000sec', 'fDie1wflow_volume_20.000sec',
#        'fDie1wflow_volume_21.000sec', 'fDie1wflow_volume_22.000sec',
#        'fDie1wflow_volume_23.000sec', 'fDie1wflow_volume_24.000sec',
#        'fDie1wflow_volume_25.000sec', 'fDie1wflow_volume_26.000sec',
# ...

# %%
core1.head()#.columns.values  #4 features with 3 time series for each features (12 time sieries) T = 0.020sec, duration =30sec
# Out:
#               File_No  core3_SQst_0.000sec  core3_SQst_0.020sec  \
# 0  B1012-278-4BM20041                    0                    0
# 1  B1012-278-4BM20042                    0                    0
# 2  B1012-278-4BM20043                    0                    0
# 3  B1012-278-4BM20044                    0                    0
# 4  B1012-278-4BM20045                    0                    0
#
#    core3_SQst_0.040sec  core3_SQst_0.060sec  core3_SQst_0.080sec  \
# 0                    1                    1                    1
# 1                    0                    0                    1
# 2                    0                    0                    1
# 3                    0                    0                    0
# 4                    0                    0                    0
#
#    core3_SQst_0.100sec  core3_SQst_0.120sec  core3_SQst_0.140sec  \
# 0                    1                    1                    2
# ...

# %%
ep0.columns.values #1 feature (electric_power) (1 time sieries) T = 0.1 duration =60sec
# Out:
# array(['File_No', 'electric_power_0.0sec', 'electric_power_0.1sec',
#        'electric_power_0.2sec', 'electric_power_0.3sec',
#        'electric_power_0.4sec', 'electric_power_0.5sec',
#        'electric_power_0.6sec', 'electric_power_0.7sec',
#        'electric_power_0.8sec', 'electric_power_0.9sec',
#        'electric_power_1.0sec', 'electric_power_1.1sec',
#        'electric_power_1.2sec', 'electric_power_1.3sec',
#        'electric_power_1.4sec', 'electric_power_1.5sec',
#        'electric_power_1.6sec', 'electric_power_1.7sec',
#        'electric_power_1.8sec', 'electric_power_1.9sec',
#        'electric_power_2.0sec', 'electric_power_2.1sec',
#        'electric_power_2.2sec', 'electric_power_2.3sec',
#        'electric_power_2.4sec', 'electric_power_2.5sec',
#        'electric_power_2.6sec', 'electric_power_2.7sec',
#        'electric_power_2.8sec', 'electric_power_2.9sec',
#        'electric_power_3.0sec', 'electric_power_3.1sec',
# ...

# %%
inj0.columns.values # 1 feature with 3 time sieries (Velocity, MetalPres, Stroke) (3 time series)  T = 0.002sec, duration =6sec
# Out:
# array(['File_No', 'Velocity_0.000sec', 'Velocity_0.002sec', ...,
#        'Stroke_5.994sec', 'Stroke_5.996sec', 'Stroke_5.998sec'],
#       dtype=object)

# %%
lub0.columns.values # 1 feature with 2 time sieries (fDie_lub_volume, mDie_lub_volume) (2 time series)  T = 0.100sec, duration =15sec
# Out:
# array(['File_No', 'fDie_lub_volume_0.000sec', 'fDie_lub_volume_0.100sec',
#        'fDie_lub_volume_0.200sec', 'fDie_lub_volume_0.300sec',
#        'fDie_lub_volume_0.400sec', 'fDie_lub_volume_0.500sec',
#        'fDie_lub_volume_0.600sec', 'fDie_lub_volume_0.700sec',
#        'fDie_lub_volume_0.800sec', 'fDie_lub_volume_0.900sec',
#        'fDie_lub_volume_1.000sec', 'fDie_lub_volume_1.100sec',
#        'fDie_lub_volume_1.200sec', 'fDie_lub_volume_1.300sec',
#        'fDie_lub_volume_1.400sec', 'fDie_lub_volume_1.500sec',
#        'fDie_lub_volume_1.600sec', 'fDie_lub_volume_1.700sec',
#        'fDie_lub_volume_1.800sec', 'fDie_lub_volume_1.900sec',
#        'fDie_lub_volume_2.000sec', 'fDie_lub_volume_2.100sec',
#        'fDie_lub_volume_2.200sec', 'fDie_lub_volume_2.300sec',
#        'fDie_lub_volume_2.400sec', 'fDie_lub_volume_2.500sec',
#        'fDie_lub_volume_2.600sec', 'fDie_lub_volume_2.700sec',
#        'fDie_lub_volume_2.800sec', 'fDie_lub_volume_2.900sec',
# ...

# %%
num0.columns.values # 1 feature with no time series in num
# Out:
# array(['File_No', 'melt_Al_wflow_temp', 'melt_Al_hight', 'Die_lub_conc',
#        'shot_Vel1', 'shot_Vel2', 'shot_Vel3', 'shot_Vel4', 'shot_Pos1',
#        'shot_Pos2', 'shot_MetalPress.', 'shot_Inten.Time', 'shot_Biscuit'],
#       dtype=object)

# %%
tie0.columns.values # 1 feature with 1 time series T = 0.002sec, duration =8sec
# Out:
# array(['File_No', 'tie_bar_strain_0.000sec', 'tie_bar_strain_0.002sec',
#        ..., 'tie_bar_strain_7.994sec', 'tie_bar_strain_7.996sec',
#        'tie_bar_strain_7.998sec'], dtype=object)

# %%
T_cool = np.arange(0,60,1)
T_core = np.arange(0,30,0.02)
T_ep = np.arange(0,60,0.1)
T_inj = np.arange(0,6,0.002)
T_lub = np.arange(0,15,0.1)
T_tie = np.arange(0,8,0.002)

# %%
#ftrs = df2.columns.values[df2.columns.str.contains('_mae')]

#for i in range(len(ftrs)):
#    ftrs[i] = ftrs[i][:-4]

#ftrs = np.concatenate((ftrs, ['melt_Al_wflow_temp', 'melt_Al_hight', 'Die_lub_conc', 'shot_Vel1',
#       'shot_Vel2', 'shot_Vel3', 'shot_Vel4', 'shot_Pos1', 'shot_Pos2',
#       'shot_MetalPress.', 'shot_Inten.Time', 'shot_Biscuit']), axis=None)

#print(ftrs)



cool_features = ['fDie1wflow','fDie2wflow','mDie1wflow','mDie2wflow','mDie3wflow','sleevewflow','tipwflow']
core_features = ['core3','core4','core5','core6']
ep_features = ['ep']
injection_features = ['injection']
lub_features = ['lub']
tiebar_features = ['tiebar']
num_features = ['melt_Al_wflow_temp', 'melt_Al_hight', 'Die_lub_conc', 'shot_Vel1','shot_Vel2', 'shot_Vel3', 'shot_Vel4', 'shot_Pos1', 'shot_Pos2','shot_MetalPress.', 'shot_Inten.Time', 'shot_Biscuit']

ftrs = [[]]*7
ftrs[0] = cool_features
ftrs[1] = core_features
ftrs[2] = ep_features
ftrs[3] = injection_features
ftrs[4] = lub_features
ftrs[5] = tiebar_features
ftrs[6] = num_features

# %%
files_clusters0 = files_clusters.iloc[0:len(cool0), :]
files_clusters1 = files_clusters.iloc[len(cool0):(len(cool0)+len(cool1)), :]
files_clusters2 = files_clusters.iloc[(len(cool0)+len(cool1)):(len(cool0)+len(cool1)+len(cool2)), :]
files_clusters3 = files_clusters.iloc[(len(cool0)+len(cool1)+len(cool2)):len(files_clusters), :]
#files_clusters.iloc[0:23041, 0].values == cool0['File_No'].values

len(files_clusters3)
# Out:
# 15425

# %%
n_clusters = len(files_clusters.cluster_label.unique())

# %%
#new_df = pd.merge(left=cool0, right=files_clusters.iloc[0:23042, :], on='File_No')
"""
cool0_df = pd.merge(left=cool0, right=files_clusters0, on='File_No')
core0_df = pd.merge(left=core0, right=files_clusters0, on='File_No')
ep0_df = pd.merge(left=ep0, right=files_clusters0, on='File_No')
inj0_df = pd.merge(left=inj0, right=files_clusters0, on='File_No')
lub0_df = pd.merge(left=lub0, right=files_clusters0, on='File_No')
num0_df = pd.merge(left=num0, right=files_clusters0, on='File_No')
tie0_df = pd.merge(left=tie0, right=files_clusters0, on='File_No')
"""



cool = pd.concat([cool0, cool1, cool2], ignore_index=True)
core = pd.concat([core0, core1, core2], ignore_index=True)
ep = pd.concat([ep0, ep1, ep2], ignore_index=True)
inj = pd.concat([inj0, inj1, inj2], ignore_index=True)
lub = pd.concat([lub0, lub1, lub2], ignore_index=True)
num = pd.concat([num0, num1, num2], ignore_index=True)
tie = pd.concat([tie0, tie1, tie2], ignore_index=True)

cool_df = pd.merge(left=cool, right=files_clusters.iloc[0:(len(cool0)+len(cool1)+len(cool2)), :], on='File_No')
core_df = pd.merge(left=core, right=files_clusters.iloc[0:(len(cool0)+len(cool1)+len(cool2)), :], on='File_No')
ep_df = pd.merge(left=ep, right=files_clusters.iloc[0:(len(cool0)+len(cool1)+len(cool2)), :], on='File_No')
inj_df = pd.merge(left=inj, right=files_clusters.iloc[0:(len(cool0)+len(cool1)+len(cool2)), :], on='File_No')
lub_df = pd.merge(left=lub, right=files_clusters.iloc[0:(len(cool0)+len(cool1)+len(cool2)), :], on='File_No')
num_df = pd.merge(left=num, right=files_clusters.iloc[0:(len(cool0)+len(cool1)+len(cool2)), :], on='File_No')
tie_df = pd.merge(left=tie, right=files_clusters.iloc[0:(len(cool0)+len(cool1)+len(cool2)), :], on='File_No')

"""
cool1_df = pd.merge(left=cool1, right=files_clusters1, on='File_No')
core1_df = pd.merge(left=core1, right=files_clusters1, on='File_No')
ep1_df = pd.merge(left=ep1, right=files_clusters1, on='File_No')
inj1_df = pd.merge(left=inj1, right=files_clusters1, on='File_No')
lub1_df = pd.merge(left=lub1, right=files_clusters1, on='File_No')
num1_df = pd.merge(left=num1, right=files_clusters1, on='File_No')
tie1_df = pd.merge(left=tie1, right=files_clusters1, on='File_No')

cool2_df = pd.merge(left=cool2, right=files_clusters2, on='File_No')
core2_df = pd.merge(left=core2, right=files_clusters2, on='File_No')
ep2_df = pd.merge(left=ep2, right=files_clusters2, on='File_No')
inj2_df = pd.merge(left=inj2, right=files_clusters2, on='File_No')
lub2_df = pd.merge(left=lub2, right=files_clusters2, on='File_No')
num2_df = pd.merge(left=num2, right=files_clusters2, on='File_No')
tie2_df = pd.merge(left=tie2, right=files_clusters2, on='File_No')

"""
#
# Out:
# C:\Users\z0041t8e\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:14: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-194-0a2fad2c7b0d> in <module>
#      13
#      14 cool = pd.concat([cool0, cool1, cool2], ignore_index=True)
# ---> 15 core = pd.concat([core0, core1, core2], ignore_index=True)
#      16 ep = pd.concat([ep0, ep1, ep2], ignore_index=True)
#      17 inj = pd.concat([inj0, inj1, inj2], ignore_index=True)
#
# ...

# %%
cluster_time_series = [[]]*8
for i in range(n_clusters):
    for u in range(len(ftrs)-1):
        for j in range(len(ftrs[u])):  
            #cluster_time_series[i] = list()
            if (np.any(pd.Index(cluster_ftrs[i]).str.contains(ftrs[u][j]))):
                cluster_time_series[i].append(ftrs[u][j])
    cluster_time_series[i] = np.asarray(np.unique(cluster_time_series[i]))

# %%
plt.figure(100)
plt.plot(cool0_df[cool0_df['cluster_label'] == 1].iloc[5, cool0_df.columns.str.contains('fDie1wflow_volume')])
# Out:
# <img src="data:image/png;base64,..." width="432">

# %%
"""
T_cool = np.arange(0,60,1)
T_core = np.arange(0,30,0.02)
T_ep = np.arange(0,60,0.1)
T_inj = np.arange(0,6,0.002)
T_lub = np.arange(0,15,0.1)
T_tie = np.arange(0,8,0.002)

cool_features = ['fDie1wflow','fDie2wflow','mDie1wflow','mDie2wflow','mDie3wflow','sleevewflow','tipwflow']
core_features = ['core3','core4','core5','core6']
ep_features = ['ep']
injection_features = ['injection']
lub_features = ['lub']
tiebar_features = ['tiebar']
"""

#Cluster 0: 14 figures
C = 1

#cooling

plt.figure(1, figsize = [14,10])
plt.subplot(211)
plt.title('fDie1wflow_volume')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('fDie1wflow_volume')])

plt.subplot(212)
plt.title('fDie1wflow_temp')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('fDie1wflow_temp')])


plt.figure(2, figsize = [14,10])
plt.subplot(211)
plt.title('fDie2wflow_volume')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('fDie2wflow_volume')])

plt.subplot(212)
plt.title('fDie2wflow_temp')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('fDie2wflow_temp')])



plt.figure(3, figsize = [14,10])
plt.subplot(211)
plt.title('mDie1wflow_volume')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('mDie1wflow_volume')])

plt.subplot(212)
plt.title('mDie1wflow_temp')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('mDie1wflow_temp')])



plt.figure(4, figsize = [14,10])
plt.subplot(211)
plt.title('mDie2wflow_volume')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('mDie2wflow_volume')])

plt.subplot(212)
plt.title('mDie2wflow_temp')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('mDie2wflow_temp')])



plt.figure(5, figsize = [14,10])
plt.subplot(211)
plt.title('mDie3wflow_volume')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('mDie3wflow_volume')])

plt.subplot(212)
plt.title('mDie3wflow_temp')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('mDie3wflow_temp')])


plt.figure(6, figsize = [14,10])
plt.subplot(211)
plt.title('sleevewflow_volume')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('sleevewflow_volume')])

plt.subplot(212)
plt.title('sleevewflow_temp')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('sleevewflow_temp')])



plt.figure(7, figsize = [14,10])
plt.subplot(211)
plt.title('tipwflow_volume')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('tipwflow_volume')])

plt.subplot(212)
plt.title('tipwflow_temp')
plt.xlabel('time (s)')
plt.plot(cool0_df[cool0_df['cluster_label'] == C].iloc[1, cool0_df.columns.str.contains('tipwflow_temp')])
# Out:
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">

# %%
#Cores
plt.figure(8, figsize = [14,14])
plt.subplot(311)
plt.title('core3_SQst')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core3_SQst')])

plt.subplot(312)
plt.title('core3_headPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core3_headPress')])

plt.subplot(313)
plt.title('core3_rodPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core3_rodPress')])


plt.figure(9, figsize = [14,14])
plt.subplot(311)
plt.title('core4_SQst')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core4_SQst')])

plt.subplot(312)
plt.title('core4_headPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core4_headPress')])

plt.subplot(313)
plt.title('core4_rodPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core4_rodPress')])




plt.figure(10, figsize = [14,14])
plt.subplot(311)
plt.title('core5_SQst')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core5_SQst')])

plt.subplot(312)
plt.title('core5_headPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core5_headPress')])

plt.subplot(313)
plt.title('core5_rodPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core5_rodPress')])



plt.figure(11, figsize = [14,14])
plt.subplot(311)
plt.title('core6_SQst')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core6_SQst')])

plt.subplot(312)
plt.title('core6_headPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core6_headPress')])

plt.subplot(313)
plt.title('core6_rodPress')
plt.xlabel('time (s)')
plt.plot(core0_df[core0_df['cluster_label'] == C].iloc[1, core0_df.columns.str.contains('core6_rodPress')])
# Out:
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">
# <img src="data:image/png;base64,..." width="1008">

# %%
#Electric Power
plt.figure(17, figsize = [14,10])
plt.title('Electric Power')
plt.xlabel('time (s)')
plt.plot(ep0_df[ep0_df['cluster_label'] == C].iloc[1, ep0_df.columns.str.contains('electric_power')])
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
#Lub
plt.figure(13, figsize = [14,10])
plt.subplot(211)
plt.title('fDie_lub_volume')
plt.xlabel('time (s)')
plt.plot(lub0_df[lub0_df['cluster_label'] == C].iloc[1, lub0_df.columns.str.contains('fDie_lub_volume')])

plt.subplot(212)
plt.title('mDie_lub_volume')
plt.xlabel('time (s)')
plt.plot(lub0_df[lub0_df['cluster_label'] == C].iloc[1, lub0_df.columns.str.contains('mDie_lub_volume')])
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
#Injection
plt.figure(14, figsize = [14,15])
plt.subplot(311)
plt.title('Velocity')
plt.xlabel('time (s)')
plt.plot(inj0_df[inj0_df['cluster_label'] == C].iloc[1, inj0_df.columns.str.contains('Velocity')])

plt.subplot(312)
plt.title('MetalPres')
plt.xlabel('time (s)')
plt.plot(inj0_df[inj0_df['cluster_label'] == C].iloc[1, inj0_df.columns.str.contains('MetalPres')])

plt.subplot(313)
plt.title('Stroke')
plt.xlabel('time (s)')
plt.plot(inj0_df[inj0_df['cluster_label'] == C].iloc[1, inj0_df.columns.str.contains('Stroke')])
# Out:
# <img src="data:image/png;base64,..." width="1008">

# %%
#Tie
plt.figure(15, figsize = [14,10])
plt.title('Tie')
plt.xlabel('time (s)')
plt.plot(tie0_df[tie0_df['cluster_label'] == C].iloc[1, tie0_df.columns.str.contains('tie_bar_strain')])
# Out:
# <img src="data:image/png;base64,..." width="1008">
